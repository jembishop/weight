# %%
import pandas as pd
import sqlite3
import matplotlib.pyplot as plt

# %%
with sqlite3.connect("C:\\Users\jembi\PycharmProjects\weight\weight") as conn:
   df = pd.read_sql_query("SELECT * FROM weight", con=conn, index_col="date")
df.index = pd.to_datetime(df.index)
df["absolute"]=df.index-df.index[0]
df.index = df["absolute"]
df.drop("absolute", axis=1)
diet_start= df.iloc[14][1]

# %%
resampled=df["weight"].resample("3D").mean()
resampled.plot()

# %%
df.plot(y="weight")

# %%
df.tail()

# %%
resampled

# %%
(103.4-97)/(32-12)

# %%
0.32*7
# Out:
# 2.24
